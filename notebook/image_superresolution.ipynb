# %%
import matplotlib.pyplot as plt

# %%
import pydaisi as pyd
image_super_resolution = pyd.Daisi("oghli/Image Super Resolution")
# Out:
# [10:25:48] INFO     Calling https://app.daisi.io/pebble-api/daisies/connect?name=oghli/Image Super   ]8;id=327609;file://c:\Users\mhdsh\AppData\Local\Programs\Python\Python39\lib\site-packages\pydaisi\pydaisi.py\pydaisi.py]8;;\:]8;id=781320;file://c:\Users\mhdsh\AppData\Local\Programs\Python\Python39\lib\site-packages\pydaisi\pydaisi.py#378\378]8;;\
#                     Resolution
# [10:25:50] INFO     Found existing Daisi: fcc5fe4e-4bf7-4f82-be23-354fa35773d0                       ]8;id=437820;file://c:\Users\mhdsh\AppData\Local\Programs\Python\Python39\lib\site-packages\pydaisi\pydaisi.py\pydaisi.py]8;;\:]8;id=462876;file://c:\Users\mhdsh\AppData\Local\Programs\Python\Python39\lib\site-packages\pydaisi\pydaisi.py#391\391]8;;\

# %%
image_source = "https://i.imgur.com/R5ovXDO.jpg"
#image_source = "images/witcher.jpg"
result = image_super_resolution.cv_superresolution(image_source).value
result
# Out:
# [10:26:04] INFO     The image sides are upsampled by a factor 4. The new image is 16 times as large  ]8;id=672641;file://c:\Users\mhdsh\AppData\Local\Programs\Python\Python39\lib\site-packages\pydaisi\pydaisi.py\pydaisi.py]8;;\:]8;id=267048;file://c:\Users\mhdsh\AppData\Local\Programs\Python\Python39\lib\site-packages\pydaisi\pydaisi.py#252\252]8;;\
#                     as the original image
# (
#     array([[[ 11,  14,  23],
#         [ 11,  14,  23],
#         [ 10,  13,  22],
#         ...,
#         [ 11,  18,  34],
#         [  8,  15,  31],
#         [  7,  14,  30]],
#
#        [[ 11,  14,  23],
#         [ 11,  14,  23],
#         [ 10,  13,  22],
#         ...,
#         [ 11,  18,  34],
#         [  8,  15,  31],
#         [  7,  14,  30]],
#
#        [[ 10,  13,  22],
#         [ 10,  13,  22],
#         [  9,  12,  21],
#         ...,
#         [ 11,  18,  34],
#         [  8,  15,  31],
#         [  7,  14,  30]],
#
#        ...,
#
#        [[  4,  16,  40],
#         [  5,  17,  41],
#         [  5,  17,  41],
#         ...,
#         [139, 143, 152],
#         [139, 143, 152],
#         [139, 143, 152]],
#
#        [[  5,  17,  41],
#         [  5,  17,  41],
#         [  5,  17,  41],
#         ...,
#         [139, 143, 152],
#         [139, 143, 152],
#         [139, 143, 152]],
#
#        [[  5,  17,  41],
#         [  5,  17,  41],
#         [  5,  17,  41],
#         ...,
#         [139, 143, 152],
#         [139, 143, 152],
#         [139, 143, 152]]], dtype=uint8),
#     array([[[  7,   9,  17],
#         [  9,  11,  19],
#         [ 11,  13,  22],
#         ...,
#         [  8,  15,  31],
#         [  7,  14,  30],
#         [  7,  14,  30]],
#
#        [[  8,  11,  20],
#         [ 12,  14,  23],
#         [ 13,  16,  25],
#         ...,
#         [  8,  15,  31],
#         [  8,  15,  31],
#         [  6,  13,  29]],
#
#        [[ 13,  16,  24],
#         [ 12,  15,  23],
#         [ 13,  16,  25],
#         ...,
#         [  8,  15,  31],
#         [  8,  15,  31],
#         [  7,  14,  30]],
#
#        ...,
#
#        [[  3,  15,  39],
#         [  3,  15,  39],
#         [  4,  17,  41],
#         ...,
#         [138, 142, 151],
#         [138, 142, 151],
#         [138, 142, 151]],
#
#        [[  3,  15,  39],
#         [  5,  17,  41],
#         [  6,  18,  41],
#         ...,
#         [138, 142, 151],
#         [138, 142, 151],
#         [138, 142, 151]],
#
#        [[  5,  17,  40],
#         [  7,  19,  42],
#         [  8,  20,  43],
#         ...,
#         [139, 143, 151],
#         [138, 142, 150],
#         [138, 142, 150]]], dtype=uint8)
# )

# %%
origin_image = result[0] 
superresolution_image = result[1]

# %%
plt.imshow(superresolution_image)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(30, 15))
ax[0].imshow(origin_image)
ax[1].imshow(superresolution_image)
ax[0].set_title("Origin")
ax[1].set_title("Superresolution")

# %%
image_source = "images/witcher.jpg"
result = image_super_resolution.cv_superresolution(image_source).value
# Out:
# [10:32:09] INFO     The image sides are upsampled by a factor 4. The new image is 16 times as large  ]8;id=348942;file://c:\Users\mhdsh\AppData\Local\Programs\Python\Python39\lib\site-packages\pydaisi\pydaisi.py\pydaisi.py]8;;\:]8;id=911266;file://c:\Users\mhdsh\AppData\Local\Programs\Python\Python39\lib\site-packages\pydaisi\pydaisi.py#252\252]8;;\
#                     as the original image

# %%
origin_image = result[0] 
superresolution_image = result[1]

# %%
plt.imshow(superresolution_image)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(30, 15))
ax[0].imshow(origin_image)
ax[1].imshow(superresolution_image)
ax[0].set_title("Origin")
ax[1].set_title("Superresolution")
